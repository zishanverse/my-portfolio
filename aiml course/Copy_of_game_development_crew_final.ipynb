# %%
# !pip install -U crewai

# %%
# !pip install "crewai[google-genai]"

# %% [markdown]
# #**Creative Game Designer Agent**
# ```
#    role="Creative Game Designer",
#
#    goal="Come up with fun, feasible game concepts and detailed mechanics based on user idea",
#
#    backstory=
#      "You are an experienced game designer."
#      "You excel at turning vague ideas into clear, exciting game designs including:"
#      "- core loop, rules, win/lose conditions"
#      "- basic entities (player, enemies, items)"
#      "- controls and feel"
#      "Keep it simple enough to implement in pure Python + Pygame in one file.",
# ```

# %%
from crewai import Agent,LLM
from google.colab import userdata

gemini_api_key = userdata.get('GEMINI_API_KEY')


llm = LLM(
   model="gemini/gemini-2.5-flash",
   api_key=gemini_api_key
)

game_designer = Agent(
    role="Creative Game Designer",
    goal="Come up with fun, feasible game concepts and detailed mechanics based on user idea",
    backstory=
      "You are an experienced game designer."
      "You excel at turning vague ideas into clear, exciting game designs including:"
      "- core loop, rules, win/lose conditions"
      "- basic entities (player, enemies, items)"
      "- controls and feel"
      "Keep it simple enough to implement in pure Python + Pygame in one file.",
    verbose=True,
    llm=llm,
)

# %%
# !pip install -U 'crewai[tools]'

# %% [markdown]
# #**Senior Python Game Developer Agent**
#
# ```
# role="Senior Python Game Developer",
#
# goal="Write clean, working Python code (using Pygame) for the described game",
#
# backstory=
#        "You are a senior software engineer specialized in Python game development with Pygame."
#        "You write structured, readable code with:"
#        "- Proper game loop, event handling, drawing"
#        "- Comments explaining key parts"
#        "- Error handling where needed"
#        "You always produce a complete, runnable .py file.",
# ```

# %%
from crewai_tools import SerperDevTool

serper_api_key = userdata.get('SERPER_API_KEY')

search_tool = SerperDevTool(api_key=serper_api_key)


senior_engineer = Agent(
   role="Senior Python Game Developer",
   goal="Write clean, working Python code (using Pygame) for the described game",
    backstory=
        "You are a senior software engineer specialized in Python game development with Pygame."
        "You write structured, readable code with:"
        "- Proper game loop, event handling, drawing"
        "- Comments explaining key parts"
        "- Error handling where needed"
        "You always produce a complete, runnable .py file.",
   verbose=True,
   llm=llm,
)

# %% [markdown]
# #**QA Engineer & Code Reviewer Agent**
#
#     role="QA Engineer & Code Reviewer",
#
#     goal="Test, review, and improve the code for bugs, playability, and completeness",
#
#     backstory=
#         "You are a meticulous QA engineer and code reviewer."
#         "You carefully check:"
#         "- Does the code run without errors?"
#         "- Does it implement ALL the designed features?"
#         "- Is it fun/playable? Any obvious balance issues?"
#         "- Code style, variable names, comments"
#         "Suggest fixes or small improvements and output the FINAL improved code.",

# %%
qa_engineer = Agent(
    role="QA Engineer & Code Reviewer",
    goal="Test, review, and improve the code for bugs, playability, and completeness",
    backstory=
        "You are a meticulous QA engineer and code reviewer."
        "You carefully check:"
        "- Does the code run without errors?"
        "- Does it implement ALL the designed features?"
        "- Is it fun/playable? Any obvious balance issues?"
        "- Code style, variable names, comments"
        "Suggest fixes or small improvements and output the FINAL improved code.",
    verbose=True,
    llm=llm,
)

# %%
from crewai import Task

# %%
task_design = Task(
    description=
        "Take the user's game idea: {game_idea}"
        "1. Clarify and expand it into a fun, simple 2D game"
        "2. Describe: objective, controls, entities, win/lose"
        "3. Keep scope small (one level, basic mechanics)"
        "Output format:"
        "## Game Design Document"
        "- Title: ..."
        "- Genre: ..."
        "- Objective: ..."
        "- Controls: ..."
        "- Entities: ..."
        "- Mechanics: ...",
    expected_output="A clear markdown Game Design Document",
    agent=game_designer
)

# %%
task_code = Task(
    description=
        "Using the game design from the previous task"
        "Write a COMPLETE, standalone Python script using Pygame that implements the game."
        "- Include import pygame, sys, random (if needed)"
        "- Full game loop, init, events, update, draw"
        "- Make it runnable with python game.py"
        "- Add simple comments"
        "- Final answer MUST be ONLY the Python code and Instructions on how to play the game",
    expected_output="A complete runnable Pygame Python script",
    agent=senior_engineer,
    context=[task_design]
)

# %%
task_review = Task(
    description=
        "Review the Python code from the previous task."
        "1. Check for syntax/runtime errors"
        "2. Verify it matches the design document"
        "3. Test mentally: does it have init, loop, quit handling, drawing?"
        "4. Suggest fixes/improvements if needed"
        "5. Output the FINAL, improved, ready-to-run code"
        "Your final answer MUST be ONLY the complete Python code along with the instructions on how to play the game",
    expected_output="Final polished, runnable Pygame Python script and instructions on how to play the game",
    agent=qa_engineer,
    context=[task_design, task_code]
)

# %%
from crewai import Crew, Process

game_crew = Crew(
      agents=[game_designer, senior_engineer, qa_engineer],
      tasks=[task_design, task_code, task_review],
      process=Process.sequential,
      verbose=True
)

# %%
game_idea = "A fun endless runner where a character jumps over obstacles"
result = game_crew.kickoff(inputs={"game_idea": game_idea})
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  0bcd74a6-cd3d-43d3-87cb-dbc359f9bf9b                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Take the user's game idea: A fun endless runner where a character jumps over obstacles1. Clarify and     │
# │  expand it into a fun, simple 2D game2. Describe: objective, controls, entities, win/lose3. Keep scope small    │
# │  (one level, basic mechanics)Output format:## Game Design Document- Title: ...- Genre: ...- Objective: ...-     │
# │  Controls: ...- Entities: ...- Mechanics: ...                                                                   │
# │  ID: 8264631c-519c-47bb-b8b5-51a5070ace2f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Game Designer                                                                                  │
# │                                                                                                                 │
# │  Task: Take the user's game idea: A fun endless runner where a character jumps over obstacles1. Clarify and     │
# │  expand it into a fun, simple 2D game2. Describe: objective, controls, entities, win/lose3. Keep scope small    │
# │  (one level, basic mechanics)Output format:## Game Design Document- Title: ...- Genre: ...- Objective: ...-     │
# │  Controls: ...- Entities: ...- Mechanics: ...                                                                   │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Game Designer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ## Game Design Document                                                                                        │
# │                                                                                                                 │
# │  -   **Title:** Pixel Pounce                                                                                    │
# │  -   **Genre:** Endless Runner, Arcade, 2D                                                                      │
# │  -   **Objective:** Survive for as long as possible by jumping over obstacles and achieve the highest score.    │
# │  -   **Controls:**                                                                                              │
# │      *   `Spacebar` or `Up Arrow Key`: Jump.                                                                    │
# │      *   `Spacebar` (on Game Over screen): Restart Game.                                                        │
# │  -   **Entities:**                                                                                              │
# │      *   **Player Character (The Sprinter):** A small, pixelated adventurer sprite (e.g., a simple block-man    │
# │  or a tiny dinosaur). It automatically runs across the screen, maintaining a fixed horizontal position while    │
# │  the game world scrolls towards it. The Sprinter has a "running" visual state (can be a simple animation or     │
# │  just a static sprite) and a "jumping" visual state.                                                            │
# │      *   **Ground (Endless Path):** A repeating horizontal strip of pixel art (e.g., grass, dirt, desert        │
# │  floor) that scrolls continuously from right to left, creating the illusion of player movement.                 │
# │      *   **Obstacles (Spiky Hazards):** Simple, ground-based static sprites such as small cacti, rocks, or      │
# │  spike traps. These objects appear on the right edge of the screen and scroll left along with the ground.       │
# │          *   For initial scope, we will have one primary type of obstacle. The challenge comes from their       │
# │  placement and density.                                                                                         │
# │      *   **Background (Distant Scenery):** Simple, non-interactive pixel art elements like distant mountains,   │
# │  clouds, or trees that scroll slower than the foreground, adding a sense of depth.                              │
# │  -   **Mechanics:**                                                                                             │
# │      *   **Automatic Forward Movement:** The player character continuously "runs" forward. This is simulated    │
# │  by having the game world (ground, obstacles, background) scroll from right to left at a constant, increasing   │
# │  speed. The player's horizontal position remains fixed relative to the screen.                                  │
# │      *   **Jumping:** Pressing the designated jump key makes the Sprinter perform a parabolic jump. The         │
# │  Sprinter moves upwards, then downwards, automatically landing back on the ground. Only one jump is allowed at  │
# │  a time (no double jumps).                                                                                      │
# │      *   **Obstacle Generation:** New obstacles are randomly generated off-screen to the right. There will be   │
# │  a minimum and maximum clear distance between obstacles to ensure fairness and prevent impossible jumps. The    │
# │  frequency and density of obstacles will increase as the game progresses and speed up.                          │
# │      *   **Collision Detection:** If the player character's bounding box (e.g., the area occupied by its feet   │
# │  or lower body) overlaps with an obstacle's bounding box while the player is on the ground or descending from   │
# │  a jump (i.e., not clearly above the obstacle), it results in a "Game Over."                                    │
# │      *   **Scoring System:**                                                                                    │
# │          *   **Survival Points:** The player earns 1 point for every 100 milliseconds survived.                 │
# │          *   **Obstacle Bonus:** An additional 10 points are awarded for successfully jumping over each         │
# │  obstacle (i.e., an obstacle scrolls past the player without collision).                                        │
# │      *   **Progressive Difficulty:** The scrolling speed of the game world (and thus the effective speed of     │
# │  the character and obstacles) gradually increases over time, making the game progressively more challenging     │
# │  and requiring quicker reflexes.                                                                                │
# │      *   **Game Over Condition:** The game ends immediately upon collision with any obstacle. The player's      │
# │  final score is displayed.                                                                                      │
# │      *   **Restart Option:** After a "Game Over," the player will be prompted to press the `Spacebar` to        │
# │  restart the game from the beginning.                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Take the user's game idea: A fun endless runner where a character jumps over obstacles1. Clarify and expand    │
# │  it into a fun, simple 2D game2. Describe: objective, controls, entities, win/lose3. Keep scope small (one      │
# │  level, basic mechanics)Output format:## Game Design Document- Title: ...- Genre: ...- Objective: ...-          │
# │  Controls: ...- Entities: ...- Mechanics: ...                                                                   │
# │  Agent:                                                                                                         │
# │  Creative Game Designer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the game design from the previous taskWrite a COMPLETE, standalone Python script using Pygame      │
# │  that implements the game.- Include import pygame, sys, random (if needed)- Full game loop, init, events,       │
# │  update, draw- Make it runnable with python game.py- Add simple comments- Final answer MUST be ONLY the Python  │
# │  code and Instructions on how to play the game                                                                  │
# │  ID: 21416114-b682-4745-952a-2fec52880e73                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Python Game Developer                                                                            │
# │                                                                                                                 │
# │  Task: Using the game design from the previous taskWrite a COMPLETE, standalone Python script using Pygame      │
# │  that implements the game.- Include import pygame, sys, random (if needed)- Full game loop, init, events,       │
# │  update, draw- Make it runnable with python game.py- Add simple comments- Final answer MUST be ONLY the Python  │
# │  code and Instructions on how to play the game                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Senior Python Game Developer                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's the complete Pygame script for "Pixel Pounce" as per your game design document.                         │
# │                                                                                                                 │
# │  ```python                                                                                                      │
# │  import pygame                                                                                                  │
# │  import sys                                                                                                     │
# │  import random                                                                                                  │
# │                                                                                                                 │
# │  # --- Game Initialization ---                                                                                  │
# │  pygame.init()                                                                                                  │
# │                                                                                                                 │
# │  # --- Screen Dimensions ---                                                                                    │
# │  SCREEN_WIDTH = 800                                                                                             │
# │  SCREEN_HEIGHT = 400                                                                                            │
# │  screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))                                                │
# │  pygame.display.set_caption("Pixel Pounce")                                                                     │
# │                                                                                                                 │
# │  # --- Colors ---                                                                                               │
# │  WHITE = (255, 255, 255)                                                                                        │
# │  BLACK = (0, 0, 0)                                                                                              │
# │  GREEN = (0, 200, 0)                                                                                            │
# │  BLUE = (100, 100, 255)                                                                                         │
# │  BROWN = (139, 69, 19)                                                                                          │
# │  GREY = (150, 150, 150)                                                                                         │
# │  DARK_GREEN = (0, 100, 0)                                                                                       │
# │                                                                                                                 │
# │  # --- Game Constants ---                                                                                       │
# │  FPS = 60                                                                                                       │
# │  GRAVITY = 0.8                                                                                                  │
# │  PLAYER_JUMP_VELOCITY = -15                                                                                     │
# │  GROUND_HEIGHT = 50  # Height of the ground strip at the bottom                                                 │
# │  GROUND_Y = SCREEN_HEIGHT - GROUND_HEIGHT                                                                       │
# │                                                                                                                 │
# │  # --- Player Properties ---                                                                                    │
# │  PLAYER_WIDTH = 30                                                                                              │
# │  PLAYER_HEIGHT = 50                                                                                             │
# │  PLAYER_START_X = 50 # Fixed horizontal position                                                                │
# │                                                                                                                 │
# │  # --- Obstacle Properties ---                                                                                  │
# │  OBSTACLE_WIDTH = 20                                                                                            │
# │  OBSTACLE_HEIGHT = 40                                                                                           │
# │  OBSTACLE_MIN_GAP = 200 # Minimum horizontal distance between obstacles                                         │
# │  OBSTACLE_MAX_GAP = 600 # Maximum horizontal distance between obstacles                                         │
# │  OBSTACLE_INITIAL_SPEED = 5 # Base speed                                                                        │
# │  OBSTACLE_SPEED_INCREMENT = 0.005 # How much speed increases per frame                                          │
# │                                                                                                                 │
# │  # --- Background Properties ---                                                                                │
# │  BACKGROUND_SCROLL_FACTOR = 0.2 # Background scrolls slower than foreground                                     │
# │                                                                                                                 │
# │  # --- Scoring ---                                                                                              │
# │  SURVIVAL_POINTS_INTERVAL_MS = 100 # Earn 1 point every 100ms                                                   │
# │  OBSTACLE_BONUS_POINTS = 10                                                                                     │
# │                                                                                                                 │
# │  # --- Fonts ---                                                                                                │
# │  font = pygame.font.Font(None, 36)                                                                              │
# │  game_over_font = pygame.font.Font(None, 72)                                                                    │
# │  score_font = pygame.font.Font(None, 48)                                                                        │
# │                                                                                                                 │
# │  # --- Game States ---                                                                                          │
# │  GAME_RUNNING = 1                                                                                               │
# │  GAME_OVER = 0                                                                                                  │
# │  game_state = GAME_RUNNING                                                                                      │
# │                                                                                                                 │
# │  # --- Player Class ---                                                                                         │
# │  class Player(pygame.sprite.Sprite):                                                                            │
# │      def __init__(self):                                                                                        │
# │          super().__init__()                                                                                     │
# │          self.image = pygame.Surface((PLAYER_WIDTH, PLAYER_HEIGHT))                                             │
# │          self.image.fill(BLUE) # Simple blue block for the player                                               │
# │          self.rect = self.image.get_rect(midbottom=(PLAYER_START_X, GROUND_Y))                                  │
# │          self.y_velocity = 0                                                                                    │
# │          self.is_jumping = False                                                                                │
# │          self.on_ground = True # Track if player is currently on the ground                                     │
# │                                                                                                                 │
# │      def jump(self):                                                                                            │
# │          if self.on_ground:                                                                                     │
# │              self.y_velocity = PLAYER_JUMP_VELOCITY                                                             │
# │              self.is_jumping = True                                                                             │
# │              self.on_ground = False                                                                             │
# │                                                                                                                 │
# │      def update(self):                                                                                          │
# │          # Apply gravity if not on ground                                                                       │
# │          if not self.on_ground:                                                                                 │
# │              self.y_velocity += GRAVITY                                                                         │
# │              self.rect.y += self.y_velocity                                                                     │
# │                                                                                                                 │
# │          # Check for landing on ground                                                                          │
# │          if self.rect.bottom >= GROUND_Y:                                                                       │
# │              self.rect.bottom = GROUND_Y                                                                        │
# │              self.y_velocity = 0                                                                                │
# │              self.is_jumping = False                                                                            │
# │              self.on_ground = True                                                                              │
# │                                                                                                                 │
# │      def draw(self, surface):                                                                                   │
# │          surface.blit(self.image, self.rect)                                                                    │
# │                                                                                                                 │
# │  # --- Obstacle Class ---                                                                                       │
# │  class Obstacle(pygame.sprite.Sprite):                                                                          │
# │      def __init__(self, x_pos):                                                                                 │
# │          super().__init__()                                                                                     │
# │          self.image = pygame.Surface((OBSTACLE_WIDTH, OBSTACLE_HEIGHT))                                         │
# │          self.image.fill(DARK_GREEN) # Simple dark green block for obstacle (e.g., cactus)                      │
# │          self.rect = self.image.get_rect(bottomleft=(x_pos, GROUND_Y))                                          │
# │          self.passed_player = False # To track if this obstacle has been jumped over                            │
# │                                                                                                                 │
# │      def update(self, game_speed):                                                                              │
# │          self.rect.x -= game_speed                                                                              │
# │                                                                                                                 │
# │      def draw(self, surface):                                                                                   │
# │          surface.blit(self.image, self.rect)                                                                    │
# │                                                                                                                 │
# │  # --- Game Variables (Resettable) ---                                                                          │
# │  player = Player()                                                                                              │
# │  obstacles = []                                                                                                 │
# │  game_speed = OBSTACLE_INITIAL_SPEED                                                                            │
# │  score = 0                                                                                                      │
# │  last_obstacle_x = SCREEN_WIDTH # Where the last obstacle ended                                                 │
# │  next_obstacle_time = 0 # Time until next obstacle can be generated                                             │
# │  last_score_update_time = pygame.time.get_ticks() # For survival points                                         │
# │  background_x = 0                                                                                               │
# │  ground_x = 0                                                                                                   │
# │                                                                                                                 │
# │  # --- Function to reset game state ---                                                                         │
# │  def reset_game():                                                                                              │
# │      global player, obstacles, game_speed, score, last_obstacle_x, next_obstacle_time, last_score_update_time,  │
# │  background_x, ground_x, game_state                                                                             │
# │      player = Player()                                                                                          │
# │      obstacles.clear()                                                                                          │
# │      game_speed = OBSTACLE_INITIAL_SPEED                                                                        │
# │      score = 0                                                                                                  │
# │      last_obstacle_x = SCREEN_WIDTH                                                                             │
# │      next_obstacle_time = 0                                                                                     │
# │      last_score_update_time = pygame.time.get_ticks()                                                           │
# │      background_x = 0                                                                                           │
# │      ground_x = 0                                                                                               │
# │      game_state = GAME_RUNNING                                                                                  │
# │                                                                                                                 │
# │  # --- Game Loop ---                                                                                            │
# │  def main_game_loop():                                                                                          │
# │      global game_state, game_speed, score, last_obstacle_x, next_obstacle_time, last_score_update_time,         │
# │  background_x, ground_x                                                                                         │
# │                                                                                                                 │
# │      clock = pygame.time.Clock()                                                                                │
# │      running = True                                                                                             │
# │                                                                                                                 │
# │      reset_game() # Initialize game state                                                                       │
# │                                                                                                                 │
# │      while running:                                                                                             │
# │          current_time = pygame.time.get_ticks()                                                                 │
# │                                                                                                                 │
# │          # --- Event Handling ---                                                                               │
# │          for event in pygame.event.get():                                                                       │
# │              if event.type == pygame.QUIT:                                                                      │
# │                  running = False                                                                                │
# │              if event.type == pygame.KEYDOWN:                                                                   │
# │                  if game_state == GAME_RUNNING:                                                                 │
# │                      if event.key == pygame.K_SPACE or event.key == pygame.K_UP:                                │
# │                          player.jump()                                                                          │
# │                  elif game_state == GAME_OVER:                                                                  │
# │                      if event.key == pygame.K_SPACE:                                                            │
# │                          reset_game()                                                                           │
# │                                                                                                                 │
# │          # --- Update Game Logic ---                                                                            │
# │          if game_state == GAME_RUNNING:                                                                         │
# │              player.update()                                                                                    │
# │                                                                                                                 │
# │              # Increase game speed gradually                                                                    │
# │              game_speed += OBSTACLE_SPEED_INCREMENT                                                             │
# │                                                                                                                 │
# │              # Scroll ground                                                                                    │
# │              ground_x = (ground_x - game_speed) % - (SCREEN_WIDTH / 2) # Use a factor of screen width for       │
# │  seamless looping                                                                                               │
# │                                                                                                                 │
# │              # Scroll background (slower)                                                                       │
# │              background_x = (background_x - game_speed * BACKGROUND_SCROLL_FACTOR) % - (SCREEN_WIDTH * 2) #     │
# │  Larger value for slower, deeper scroll                                                                         │
# │                                                                                                                 │
# │              # Obstacle Generation                                                                              │
# │              if current_time > next_obstacle_time:                                                              │
# │                  # Calculate next obstacle's X position based on last obstacle                                  │
# │                  next_x_pos = last_obstacle_x + random.randint(int(OBSTACLE_MIN_GAP * (1 / (game_speed /        │
# │  OBSTACLE_INITIAL_SPEED))), int(OBSTACLE_MAX_GAP * (1 / (game_speed / OBSTACLE_INITIAL_SPEED))))                │
# │                  # Ensure it's off-screen to the right                                                          │
# │                  if next_x_pos < SCREEN_WIDTH:                                                                  │
# │                      next_x_pos = SCREEN_WIDTH + random.randint(50, 100) # Start a bit more off-screen          │
# │                                                                                                                 │
# │                  new_obstacle = Obstacle(next_x_pos)                                                            │
# │                  obstacles.append(new_obstacle)                                                                 │
# │                  last_obstacle_x = new_obstacle.rect.right                                                      │
# │                  # Set a random time for the *next* obstacle generation check                                   │
# │                  next_obstacle_time = current_time + random.randint(700, 2000) # milliseconds                   │
# │                                                                                                                 │
# │              # Update and remove obstacles                                                                      │
# │              for obstacle in list(obstacles): # Iterate over a copy to allow modification                       │
# │                  obstacle.update(game_speed)                                                                    │
# │                  if obstacle.rect.right < 0:                                                                    │
# │                      obstacles.remove(obstacle)                                                                 │
# │                                                                                                                 │
# │                  # Collision Detection                                                                          │
# │                  # Check for collision only if player is not clearly above the obstacle                         │
# │                  if player.rect.colliderect(obstacle.rect):                                                     │
# │                      # Refine collision: check if player's bottom part is colliding                             │
# │                      # This helps avoid collision when player is clearly over the obstacle                      │
# │                      if player.rect.bottom > obstacle.rect.top + 5: # Small buffer                              │
# │                          game_state = GAME_OVER                                                                 │
# │                          # print(f"Game Over! Player rect: {player.rect}, Obstacle rect: {obstacle.rect}")      │
# │                                                                                                                 │
# │                  # Obstacle Bonus Scoring                                                                       │
# │                  if not obstacle.passed_player and obstacle.rect.right < player.rect.left:                      │
# │                      score += OBSTACLE_BONUS_POINTS                                                             │
# │                      obstacle.passed_player = True # Mark as scored                                             │
# │                                                                                                                 │
# │              # Survival Scoring                                                                                 │
# │              if current_time - last_score_update_time >= SURVIVAL_POINTS_INTERVAL_MS:                           │
# │                  score += 1                                                                                     │
# │                  last_score_update_time = current_time                                                          │
# │                                                                                                                 │
# │          # --- Drawing ---                                                                                      │
# │          screen.fill(WHITE) # Sky color                                                                         │
# │                                                                                                                 │
# │          # Draw Background (distant mountains/clouds)                                                           │
# │          # We can draw two instances to create a seamless loop                                                  │
# │          pygame.draw.rect(screen, GREY, (background_x, SCREEN_HEIGHT - 150, SCREEN_WIDTH * 2, 50)) # Distant    │
# │  mountains                                                                                                      │
# │          pygame.draw.rect(screen, GREY, (background_x + SCREEN_WIDTH * 2, SCREEN_HEIGHT - 150, SCREEN_WIDTH *   │
# │  2, 50))                                                                                                        │
# │                                                                                                                 │
# │          pygame.draw.ellipse(screen, WHITE, (background_x + 50, 50, 100, 50)) # Cloud 1                         │
# │          pygame.draw.ellipse(screen, WHITE, (background_x + 200, 70, 80, 40)) # Cloud 2                         │
# │          pygame.draw.ellipse(screen, WHITE, (background_x + 50 + SCREEN_WIDTH * 2, 50, 100, 50)) # Cloud 1      │
# │  (looping)                                                                                                      │
# │          pygame.draw.ellipse(screen, WHITE, (background_x + 200 + SCREEN_WIDTH * 2, 70, 80, 40)) # Cloud 2      │
# │  (looping)                                                                                                      │
# │                                                                                                                 │
# │          # Draw Ground                                                                                          │
# │          pygame.draw.rect(screen, BROWN, (ground_x, GROUND_Y, SCREEN_WIDTH * 2, GROUND_HEIGHT)) # Bottom layer  │
# │          pygame.draw.rect(screen, GREEN, (ground_x, GROUND_Y - 10, SCREEN_WIDTH * 2, 10)) # Top grass layer     │
# │          # Draw a second set of ground elements for seamless looping                                            │
# │          pygame.draw.rect(screen, BROWN, (ground_x + SCREEN_WIDTH * 2, GROUND_Y, SCREEN_WIDTH * 2,              │
# │  GROUND_HEIGHT))                                                                                                │
# │          pygame.draw.rect(screen, GREEN, (ground_x + SCREEN_WIDTH * 2, GROUND_Y - 10, SCREEN_WIDTH * 2, 10))    │
# │                                                                                                                 │
# │                                                                                                                 │
# │          # Draw Obstacles                                                                                       │
# │          for obstacle in obstacles:                                                                             │
# │              obstacle.draw(screen)                                                                              │
# │                                                                                                                 │
# │          # Draw Player                                                                                          │
# │          player.draw(screen)                                                                                    │
# │                                                                                                                 │
# │          # Draw Score                                                                                           │
# │          score_text = score_font.render(f"Score: {score}", True, BLACK)                                         │
# │          screen.blit(score_text, (10, 10))                                                                      │
# │                                                                                                                 │
# │          # Game Over Screen                                                                                     │
# │          if game_state == GAME_OVER:                                                                            │
# │              game_over_text = game_over_font.render("GAME OVER", True, BLACK)                                   │
# │              game_over_rect = game_over_text.get_rect(center=(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2 - 30))      │
# │              screen.blit(game_over_text, game_over_rect)                                                        │
# │                                                                                                                 │
# │              final_score_text = score_font.render(f"Final Score: {score}", True, BLACK)                         │
# │              final_score_rect = final_score_text.get_rect(center=(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2 + 20))  │
# │              screen.blit(final_score_text, final_score_rect)                                                    │
# │                                                                                                                 │
# │              restart_text = font.render("Press SPACE to restart", True, BLACK)                                  │
# │              restart_rect = restart_text.get_rect(center=(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2 + 70))          │
# │              screen.blit(restart_text, restart_rect)                                                            │
# │                                                                                                                 │
# │          pygame.display.flip()                                                                                  │
# │                                                                                                                 │
# │          # Cap the frame rate                                                                                   │
# │          clock.tick(FPS)                                                                                        │
# │                                                                                                                 │
# │      pygame.quit()                                                                                              │
# │      sys.exit()                                                                                                 │
# │                                                                                                                 │
# │  # Run the game                                                                                                 │
# │  if __name__ == '__main__':                                                                                     │
# │      main_game_loop()                                                                                           │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  ### Instructions on how to play the game:                                                                      │
# │                                                                                                                 │
# │  1.  **Save the code:** Save the code above as `pixel_pounce.py`.                                               │
# ...
#
#     *   **Seamless Looping of Ground and Background:**
#         *   **Issue:** The original ground scrolling logic `ground_x = (ground_x - game_speed) % - (SCREEN_WIDTH / 2)` combined with drawing two `SCREEN_WIDTH * 2` rectangles was inconsistent and could lead to visual glitches or non-seamless loops, especially if `SCREEN_WIDTH / 2` was not a clean divisor of the total visual pattern width.
#         *   **Fix:** Simplified the looping. Now, for the ground, two `SCREEN_WIDTH` wide segments are drawn, and `ground_x` is reset when it scrolls past `-SCREEN_WIDTH`. For the background, two `SCREEN_WIDTH * 2` wide segments (representing the full mountain/cloud pattern) are drawn, and `background_x` is reset when it scrolls past `-(SCREEN_WIDTH * 2)`. This ensures a clean, continuous loop.
#
#     *   **Progressive Difficulty - Obstacle Generation Rate:**
#         *   **Issue:** While the *gap* between obstacles scaled with speed, the *time interval* between generating new obstacles (`next_obstacle_time`) was fixed. This meant that as speed increased, obstacles would pass faster, potentially making the game feel less dense, which contradicts "frequency and density of obstacles will increase as the game progresses."
#         *   **Fix:** Introduced `OBSTACLE_MIN_SPAWN_INTERVAL_MS` and `OBSTACLE_MAX_SPAWN_INTERVAL_MS`. The actual spawn interval is now calculated by dividing these constants by the `speed_factor`, ensuring that obstacles are generated more frequently as the game speeds up. Added `max()` calls to prevent intervals from becoming too small (e.g., <= 0) or gaps from becoming unplayable.
#
#     *   **Obstacle Gap Scaling:**
#         *   **Improvement:** Added `max(PLAYER_WIDTH * 2, ...)` to `min_gap` calculation to ensure that even at very high speeds, there's always a minimum jumpable distance, preventing impossible scenarios. Also added a small buffer check for `max_gap < min_gap`.
#
#     *   **Initial Obstacle Placement:**
#         *   **Improvement:** Removed the conditional `if next_x_pos < SCREEN_WIDTH` block. With `last_obstacle_x` initialized to `SCREEN_WIDTH` and the `gap` added, the first obstacle will correctly appear off-screen to the right.
#
#     *   **Code Clarity:**
#         *   Added constants for obstacle spawn intervals for better readability and configurability.
#         *   Added comments where logic was modified or clarified.
#
# ### Conclusion:
# The original code was well-structured and implemented most features correctly. The primary areas for improvement were the seamless scrolling of background/ground elements and a more robust scaling of obstacle generation frequency and density to match the progressive difficulty requirement. These improvements make the game more polished and complete according to the design document.
#
# ---
#
# ### FINAL, Improved, Ready-to-Run Code:
#
# ```python
# import pygame
# import sys
# import random
#
# # --- Game Initialization ---
# pygame.init()
#
# # --- Screen Dimensions ---
# SCREEN_WIDTH = 800
# SCREEN_HEIGHT = 400
# screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
# pygame.display.set_caption("Pixel Pounce")
#
# # --- Colors ---
# WHITE = (255, 255, 255)
# BLACK = (0, 0, 0)
# GREEN = (0, 200, 0)
# BLUE = (100, 100, 255)
# BROWN = (139, 69, 19)
# GREY = (150, 150, 150)
# DARK_GREEN = (0, 100, 0)
# LIGHT_BLUE = (173, 216, 230) # Sky color
#
# # --- Game Constants ---
# FPS = 60
# GRAVITY = 0.8
# PLAYER_JUMP_VELOCITY = -15
# GROUND_HEIGHT = 50  # Height of the ground strip at the bottom
# GROUND_Y = SCREEN_HEIGHT - GROUND_HEIGHT
#
# # --- Player Properties ---
# PLAYER_WIDTH = 30
# PLAYER_HEIGHT = 50
# PLAYER_START_X = 50 # Fixed horizontal position
#
# # --- Obstacle Properties ---
# OBSTACLE_WIDTH = 20
# OBSTACLE_HEIGHT = 40
# OBSTACLE_MIN_GAP = 200 # Minimum horizontal distance between obstacles
# OBSTACLE_MAX_GAP = 600 # Maximum horizontal distance between obstacles
# OBSTACLE_INITIAL_SPEED = 5 # Base speed
# OBSTACLE_SPEED_INCREMENT = 0.005 # How much speed increases per frame
# OBSTACLE_MIN_SPAWN_INTERVAL_MS = 700 # Base min time until next obstacle can be generated
# OBSTACLE_MAX_SPAWN_INTERVAL_MS = 2000 # Base max time until next obstacle can be generated
#
# # --- Background Properties ---
# BACKGROUND_SCROLL_FACTOR = 0.2 # Background scrolls slower than foreground
#
# # --- Scoring ---
# SURVIVAL_POINTS_INTERVAL_MS = 100 # Earn 1 point every 100ms
# OBSTACLE_BONUS_POINTS = 10
#
# # --- Fonts ---
# font = pygame.font.Font(None, 36)
# game_over_font = pygame.font.Font(None, 72)
# score_font = pygame.font.Font(None, 48)
#
# # --- Game States ---
# GAME_RUNNING = 1
# GAME_OVER = 0
# game_state = GAME_RUNNING
#
# # --- Player Class ---
# class Player(pygame.sprite.Sprite):
#     def __init__(self):
#         super().__init__()
#         self.image = pygame.Surface((PLAYER_WIDTH, PLAYER_HEIGHT))
#         self.image.fill(BLUE) # Simple blue block for the player
#         self.rect = self.image.get_rect(midbottom=(PLAYER_START_X, GROUND_Y))
#         self.y_velocity = 0
#         self.is_jumping = False
#         self.on_ground = True # Track if player is currently on the ground
#
#     def jump(self):
#         if self.on_ground:
#             self.y_velocity = PLAYER_JUMP_VELOCITY
#             self.is_jumping = True
#             self.on_ground = False
#
#     def update(self):
#         # Apply gravity if not on ground
#         if not self.on_ground:
#             self.y_velocity += GRAVITY
#             self.rect.y += self.y_velocity
#
#         # Check for landing on ground
#         if self.rect.bottom >= GROUND_Y:
#             self.rect.bottom = GROUND_Y
#             self.y_velocity = 0
#             self.is_jumping = False
#             self.on_ground = True
#
#     def draw(self, surface):
#         surface.blit(self.image, self.rect)
#
# # --- Obstacle Class ---
# class Obstacle(pygame.sprite.Sprite):
#     def __init__(self, x_pos):
#         super().__init__()
#         self.image = pygame.Surface((OBSTACLE_WIDTH, OBSTACLE_HEIGHT))
#         self.image.fill(DARK_GREEN) # Simple dark green block for obstacle (e.g., cactus)
#         self.rect = self.image.get_rect(bottomleft=(x_pos, GROUND_Y))
#         self.passed_player = False # To track if this obstacle has been jumped over
#
#     def update(self, game_speed):
#         self.rect.x -= game_speed
#
#     def draw(self, surface):
#         surface.blit(self.image, self.rect)
#
# # --- Game Variables (Resettable) ---
# player = Player()
# obstacles = []
# game_speed = OBSTACLE_INITIAL_SPEED
# score = 0
# last_obstacle_x = SCREEN_WIDTH # Where the last obstacle ended on screen
# next_obstacle_time = 0 # Time until next obstacle can be generated
# last_score_update_time = pygame.time.get_ticks() # For survival points
# background_x = 0
# ground_x = 0
#
# # --- Function to reset game state ---
# def reset_game():
#     global player, obstacles, game_speed, score, last_obstacle_x, next_obstacle_time, last_score_update_time, background_x, ground_x, game_state
#     player = Player()
#     obstacles.clear()
#     game_speed = OBSTACLE_INITIAL_SPEED
#     score = 0
#     last_obstacle_x = SCREEN_WIDTH # Reset to start generating off-screen
#     next_obstacle_time = 0 # Allow immediate obstacle generation check
#     last_score_update_time = pygame.time.get_ticks()
#     background_x = 0
#     ground_x = 0
#     game_state = GAME_RUNNING
#
# # --- Game Loop ---
# def main_game_loop():
#     global game_state, game_speed, score, last_obstacle_x, next_obstacle_time, last_score_update_time, background_x, ground_x
#
#     clock = pygame.time.Clock()
#     running = True
#
#     reset_game() # Initialize game state
#
#     while running:
#         current_time = pygame.time.get_ticks()
#
#         # --- Event Handling ---
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 running = False
#             if event.type == pygame.KEYDOWN:
#                 if game_state == GAME_RUNNING:
#                     if event.key == pygame.K_SPACE or event.key == pygame.K_UP:
#                         player.jump()
#                 elif game_state == GAME_OVER:
#                     if event.key == pygame.K_SPACE:
#                         reset_game()
#
#         # --- Update Game Logic ---
#         if game_state == GAME_RUNNING:
#             player.update()
#
#             # Increase game speed gradually
#             game_speed += OBSTACLE_SPEED_INCREMENT
#
#             # --- Scrolling Ground ---
#             ground_x -= game_speed
#             # If the first ground segment scrolls completely off-screen, reset its position
#             if ground_x <= -SCREEN_WIDTH:
#                 ground_x += SCREEN_WIDTH
#
#             # --- Scrolling Background (slower) ---
#             background_x -= game_speed * BACKGROUND_SCROLL_FACTOR
#             # The background pattern (mountains + clouds) is designed to repeat every SCREEN_WIDTH * 2.
#             # When the first instance of this pattern scrolls off-screen, reset its position.
#             if background_x <= -(SCREEN_WIDTH * 2):
#                 background_x += (SCREEN_WIDTH * 2)
#
#             # --- Obstacle Generation ---
#             if current_time > next_obstacle_time:
#                 speed_factor = game_speed / OBSTACLE_INITIAL_SPEED # How much faster we are than initial speed
#                 if speed_factor < 1: # Prevent division by zero or very small numbers
#                     speed_factor = 1
#
#                 # Calculate gap, reducing with speed increase
#                 # Ensure a minimum jumpable gap, e.g., at least twice player width
#                 min_gap_actual = max(PLAYER_WIDTH * 2, int(OBSTACLE_MIN_GAP / speed_factor))
#                 max_gap_actual = int(OBSTACLE_MAX_GAP / speed_factor)
#
#                 # Ensure max_gap is not less than min_gap if speed_factor becomes very large
#                 if max_gap_actual < min_gap_actual:
#                     max_gap_actual = min_gap_actual + OBSTACLE_WIDTH * 2 # Add a buffer
#
#                 gap = random.randint(min_gap_actual, max_gap_actual)
#
#                 next_x_pos = last_obstacle_x + gap
#
#                 new_obstacle = Obstacle(next_x_pos)
#                 obstacles.append(new_obstacle)
#                 last_obstacle_x = new_obstacle.rect.right
#
#                 # Calculate next spawn time, decreasing interval with speed increase
#                 # Cap min interval at a reasonable value (e.g., 100ms) to prevent overly rapid spawns
#                 min_spawn_interval_actual = max(100, int(OBSTACLE_MIN_SPAWN_INTERVAL_MS / speed_factor))
#                 max_spawn_interval_actual = int(OBSTACLE_MAX_SPAWN_INTERVAL_MS / speed_factor)
#
#                 if max_spawn_interval_actual < min_spawn_interval_actual:
#                     max_spawn_interval_actual = min_spawn_interval_actual + 200 # Add a buffer
#
#                 next_obstacle_time = current_time + random.randint(min_spawn_interval_actual, max_spawn_interval_actual)
#
#             # Update and remove obstacles
#             for obstacle in list(obstacles): # Iterate over a copy to allow modification
#                 obstacle.update(game_speed)
#                 if obstacle.rect.right < 0:
#                     obstacles.remove(obstacle)
#
#                 # Collision Detection
#                 # Check for collision only if player is not clearly above the obstacle
#                 if player.rect.colliderect(obstacle.rect):
#                     # Refine collision: check if player's bottom part is colliding
#                     # This helps avoid collision when player is clearly over the obstacle
#                     if player.rect.bottom > obstacle.rect.top + 5: # Small buffer
#                         game_state = GAME_OVER
#
#                 # Obstacle Bonus Scoring
#                 if not obstacle.passed_player and obstacle.rect.right < player.rect.left:
#                     score += OBSTACLE_BONUS_POINTS
#                     obstacle.passed_player = True # Mark as scored
#
#             # Survival Scoring
#             if current_time - last_score_update_time >= SURVIVAL_POINTS_INTERVAL_MS:
#                 score += 1
#                 last_score_update_time = current_time
#
#         # --- Drawing ---
#         screen.fill(LIGHT_BLUE) # Sky color
#
#         # Draw Background (distant mountains/clouds) - draw two sets for seamless looping
#         # Each "pattern" is SCREEN_WIDTH * 2 wide (the mountain + its empty space)
#         # Pattern 1
#         pygame.draw.rect(screen, GREY, (background_x, SCREEN_HEIGHT - 150, SCREEN_WIDTH * 2, 50)) # Distant mountains
#         pygame.draw.ellipse(screen, WHITE, (background_x + 50, 50, 100, 50)) # Cloud 1
#         pygame.draw.ellipse(screen, WHITE, (background_x + 200, 70, 80, 40)) # Cloud 2
#         # Pattern 2 (shifted by one full pattern width)
#         pygame.draw.rect(screen, GREY, (background_x + SCREEN_WIDTH * 2, SCREEN_HEIGHT - 150, SCREEN_WIDTH * 2, 50))
#         pygame.draw.ellipse(screen, WHITE, (background_x + 50 + SCREEN_WIDTH * 2, 50, 100, 50))
#         pygame.draw.ellipse(screen, WHITE, (background_x + 200 + SCREEN_WIDTH * 2, 70, 80, 40))
#
#         # Draw Ground - draw two segments for continuous loop
#         # Each segment is SCREEN_WIDTH wide
#         pygame.draw.rect(screen, BROWN, (ground_x, GROUND_Y, SCREEN_WIDTH, GROUND_HEIGHT)) # Bottom layer
#         pygame.draw.rect(screen, GREEN, (ground_x, GROUND_Y - 10, SCREEN_WIDTH, 10)) # Top grass layer
#         # Second set of ground elements
#         pygame.draw.rect(screen, BROWN, (ground_x + SCREEN_WIDTH, GROUND_Y, SCREEN_WIDTH, GROUND_HEIGHT))
#         pygame.draw.rect(screen, GREEN, (ground_x + SCREEN_WIDTH, GROUND_Y - 10, SCREEN_WIDTH, 10))
#
#
#         # Draw Obstacles
#         for obstacle in obstacles:
#             obstacle.draw(screen)
#
#         # Draw Player
#         player.draw(screen)
#
#         # Draw Score
#         score_text = score_font.render(f"Score: {score}", True, BLACK)
#         screen.blit(score_text, (10, 10))
#
#         # Game Over Screen
#         if game_state == GAME_OVER:
#             game_over_text = game_over_font.render("GAME OVER", True, BLACK)
#             game_over_rect = game_over_text.get_rect(center=(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2 - 30))
#             screen.blit(game_over_text, game_over_rect)
#
#             final_score_text = score_font.render(f"Final Score: {score}", True, BLACK)
#             final_score_rect = final_score_text.get_rect(center=(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2 + 20))
#             screen.blit(final_score_text, final_score_rect)
#
#             restart_text = font.render("Press SPACE to restart", True, BLACK)
#             restart_rect = restart_text.get_rect(center=(SCREEN_WIDTH // 2, SCREEN_HEIGHT // 2 + 70))
#             screen.blit(restart_text, restart_rect)
#
#         pygame.display.flip()
#
#         # Cap the frame rate
#         clock.tick(FPS)
#
#     pygame.quit()
#     sys.exit()
#
# # Run the game
# if __name__ == '__main__':
#     main_game_loop()
# ```
#
# ### Instructions on how to play the game:
#
# 1.  **Save the code:** Save the code above as `pixel_pounce.py`.
# 2.  **Run the game:** Open a terminal or command prompt, navigate to the directory where you saved the file, and run: `python pixel_pounce.py`
# 3.  **Objective:** The goal is to survive as long as possible by jumping over obstacles and achieving the highest score.
# 4.  **Controls:**
#     *   **Jump:** Press the `Spacebar` or `Up Arrow Key` to make your character jump.
#     *   **Restart Game:** After a "GAME OVER" screen appears, press the `Spacebar` to restart the game.
# 5.  **Gameplay:**
#     *   Your character (the blue block) runs automatically across the screen.
#     *   Obstacles (dark green blocks) will appear from the right and scroll towards you.
#     *   Jump over the obstacles to avoid collision. You can only jump once while in the air.
#     *   The game speed will gradually increase, making it more challenging over time, with obstacles appearing closer together and more frequently.
#     *   You earn 1 point for every 100 milliseconds you survive and an additional 10 points for successfully jumping over each obstacle.
# 6.  **Game Over:** If your character collides with an obstacle, the game ends, and your final score is displayed.

# %%
# %%writefile main.py
### Paste your code here
# Out:
# Overwriting main.py

# %% [markdown]
# # **Do not edit any of the below code**

# %%
# Install required packages
# !pip install pygbag pyngrok -q

# %% [markdown]
# # **How to get pyngrok API Key?**
# - Go to https://dashboard.ngrok.com/get-started/your-authtoken
# - Copy your authtoken
# - Run this cell with YOUR token:

# %%
# !ngrok authtoken 'Auth_token'
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import subprocess
import time
from pyngrok import ngrok

# Step 1: Build the game
print("🔨 Building game...")
build_result = subprocess.run(['pygbag', '--build', 'main.py'], capture_output=True, text=True)
print(build_result.stdout)

if build_result.returncode != 0:
    print("❌ Build failed:")
    print(build_result.stderr)
else:
    print("✅ Build successful!")

    # Step 2: Start HTTP server
    print("\n🚀 Starting server...")
    server = subprocess.Popen(
        ['python', '-m', 'http.server', '8000', '--directory', '/content/build/web'],
        stdout=subprocess.PIPE,
        stderr=subprocess.PIPE
    )

    # Wait for server to start
    time.sleep(5)

    # Step 3: Create ngrok tunnel
    try:
        print("🌐 Creating public URL...")
        public_url = ngrok.connect(8000)

        print("\n" + "="*60)
        print("🎮 YOUR GAME IS READY!")
        print("="*60)
        print(f"\n🔗 Click here to play: {public_url}")
        print("\n📝 How to play:")
        print("   • Press SPACE or Click to jump")
        print("="*60)

    except Exception as e:
        print(f"\n❌ Error creating tunnel: {e}")
        print("\n💡 Make sure you ran Cell 3 with a valid ngrok token")
# Out:
# 🔨 Building game...
#
# Serving python files from [/content/build/web]
#
# with no security/performance in mind, i'm just a test tool : don't rely on me
#
#
# SUMMARY
# ________________________
#
# # the app folder
# app_folder=/content
#
# # artefacts directory
# build_dir=/content/build/web
#
# # cache directory
# cache=/content/build/web-cache
#
# # the window title and icon name
# app_name=content
#
# # package name, better make it unique
# package=web.pygame.content-1770631226
#
# # icons:  96x96 for desktop, 16x16 for web
# icon=favicon.png
#
# # js/wasm provider
# cdn=https://pygame-web.github.io/archives/0.9/
#
# now packing application ....
#
#
# Now in /
#      /main.py
# Now in /sample_data
#      /sample_data/README.md
#      /sample_data/anscombe.json
#      /sample_data/california_housing_test.csv
#      /sample_data/california_housing_train.csv
#      /sample_data/mnist_train_small.csv
#      /sample_data/mnist_test.csv
# optimizing /content
# 	/content : main.py
# 	/content : sample_data/README.md
# 	/content : sample_data/anscombe.json
# 	/content : sample_data/california_housing_test.csv
# 	/content : sample_data/california_housing_train.csv
# 	/content : sample_data/mnist_train_small.csv
# 	/content : sample_data/mnist_test.csv
# packing 7 files complete
#
#     building from local cached template https://pygame-web.github.io/archives/0.9/default.tmpl
#     cached at /content/build/web-cache/489f66f53e526d7110d2d34527229eca.tmpl
#     result files will be in /content/build/web
#
#
#     using icon from local cached file https://pygame-web.github.io/archives/0.9/favicon.png
#     cached at /content/build/web-cache/38e02d124325c756243ee99a92e528ed.png
#
#     build only requested, not running testserver, files ready here :
#
# build_dir = /content/build/web
#
#
#
# ✅ Build successful!
#
# 🚀 Starting server...
# 🌐 Creating public URL...
#
# ============================================================
# 🎮 YOUR GAME IS READY!
# ============================================================
#
# 🔗 Click here to play: NgrokTunnel: "https://unopulent-sublittoral-lady.ngrok-free.dev" -> "http://localhost:8000"
#
# 📝 How to play:
#    • Press SPACE or Click to jump
# ============================================================
